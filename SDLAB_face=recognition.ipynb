# %%
#here i have created the file and added it to my github 
# !git clone https://github.com/VinayakKalyanshetti/face_recognition
# Out:
# Cloning into 'face_recognition'...
# remote: Enumerating objects: 105, done.
# remote: Total 105 (delta 0), reused 0 (delta 0), pack-reused 105
# Receiving objects: 100% (105/105), 1.67 MiB | 1.57 MiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %%
#to run commands use ! before the line 
# !pip install face_recognition
# Out:
# Collecting face_recognition
#   Downloading https://files.pythonhosted.org/packages/1e/95/f6c9330f54ab07bfa032bf3715c12455a381083125d8880c43cbe76bb3d0/face_recognition-1.3.0-py2.py3-none-any.whl
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from face_recognition) (7.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from face_recognition) (1.18.5)
# Collecting face-recognition-models>=0.3.0
#   Downloading https://files.pythonhosted.org/packages/cf/3b/4fd8c534f6c0d1b80ce0973d01331525538045084c73c153ee6df20224cf/face_recognition_models-0.3.0.tar.gz (100.1MB)
#      |████████████████████████████████| 100.2MB 74kB/s
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.6/dist-packages (from face_recognition) (7.1.2)
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.6/dist-packages (from face_recognition) (19.18.0)
# Building wheels for collected packages: face-recognition-models
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566172 sha256=3ddba75105e16b64db199849d94b8522af4357c149147fc2f00ba97f057bf054
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face-recognition
# Successfully installed face-recognition-1.3.0 face-recognition-models-0.3.0

# %%
#go to runtime change runtime and select gpu then okay

# %%
#pip install evertying he given

# %%
ls
# Out:
# known_faces/  unknown_faces/

# %%
cd /content/face_recognition/FACERECOGNITION
# Out:
# /content/face_recognition/FACERECOGNITION

# %%
import face_recognition
import os
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


KNOWN_FACES_DIR = 'known_faces'
UNKNOWN_FACES_DIR = 'unknown_faces'
TOLERANCE = 0.59
FRAME_THICKNESS = 3
FONT_THICKNESS = 2
MODEL = 'cnn'  # default: 'hog', other one can be 'cnn' - CUDA accelerated (if available) deep-learning pretrained model


# Returns (R, G, B) from name
def name_to_color(name):
    # Take 3 first letters, tolower()
    # lowercased character ord() value rage is 97 to 122, substract 97, multiply by 8
    color = [(ord(c.lower())-97)*8 for c in name[:3]]
    return color


print('Loading known faces...')
known_faces = []
known_names = []

# We oranize known faces as subfolders of KNOWN_FACES_DIR
# Each subfolder's name becomes our label (name)
for name in os.listdir(KNOWN_FACES_DIR):

    # Next we load every file of faces of known person
    for filename in os.listdir(f'{KNOWN_FACES_DIR}/{name}'):

        # Load an image
        image = face_recognition.load_image_file(f'{KNOWN_FACES_DIR}/{name}/{filename}')

        # Get 128-dimension face encoding
        # Always returns a list of found faces, for this purpose we take first face only (assuming one face per image as you can't be twice on one image)
        encoding = face_recognition.face_encodings(image)[0]

        # Append encodings and name
        known_faces.append(encoding)
        known_names.append(name)


print('Processing unknown faces...')
# Now let's loop over a folder of faces we want to label
for filename in os.listdir(UNKNOWN_FACES_DIR):

    # Load image
    print(f'Filename {filename}', end='')
    image = face_recognition.load_image_file(f'{UNKNOWN_FACES_DIR}/{filename}')

    # This time we first grab face locations - we'll need them to draw boxes
    locations = face_recognition.face_locations(image, model=MODEL)

    # Now since we know loctions, we can pass them to face_encodings as second argument
    # Without that it will search for faces once again slowing down whole process
    encodings = face_recognition.face_encodings(image, locations)

    # We passed our image through face_locations and face_encodings, so we can modify it
    # First we need to convert it from RGB to BGR as we are going to work with cv2
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

    # But this time we assume that there might be more faces in an image - we can find faces of dirrerent people
    print(f', found {len(encodings)} face(s)')
    for face_encoding, face_location in zip(encodings, locations):

        # We use compare_faces (but might use face_distance as well)
        # Returns array of True/False values in order of passed known_faces
        results = face_recognition.compare_faces(known_faces, face_encoding, TOLERANCE)

        # Since order is being preserved, we check if any face was found then grab index
        # then label (name) of first matching known face withing a tolerance
        match = None
        if True in results:  # If at least one is true, get a name of first of found labels
            match = known_names[results.index(True)]
            print(f' - {match} from {results}')

            # Each location contains positions in order: top, right, bottom, left
            top_left = (face_location[3], face_location[0])
            bottom_right = (face_location[1], face_location[2])

            # Get color by name using our fancy function
            color = name_to_color(match)

            # Paint frame
            cv2.rectangle(image, top_left, bottom_right, color, FRAME_THICKNESS)

            # Now we need smaller, filled grame below for a name
            # This time we use bottom in both corners - to start from bottom and move 50 pixels down
            top_left = (face_location[3], face_location[2])
            bottom_right = (face_location[1], face_location[2] + 22)

            # Paint frame
            cv2.rectangle(image, top_left, bottom_right, color, cv2.FILLED)

            # Wite a name
            cv2.putText(image, match, (face_location[3] + 10, face_location[2] + 15), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (200, 200, 200), FONT_THICKNESS)

    # Show image
    #cv2.destroyWindow(filename)
    #cv2.waitKey(0)
    #cv2.imshow(filename, image)
    plt.figure()
 
    plt.show()
    
    #imgplot = plt.showimshow(image)
    #plt.show()
    
    plt.figure()
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    #plt.imshow(image)
    plt.show()
# Out:
# Loading known faces...
# Processing unknown faces...
# Filename 12.jpg, found 1 face(s)
#  - Sundar_Pichai from [True, True, True, True, True, False, True, True, True, True, True, True, True, True]
# Filename 13.jpg, found 1 face(s)
#  - Sundar_Pichai from [True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# Filename 2.jpg, found 1 face(s)
#  - Sundar_Pichai from [True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# Filename 9.jpg, found 1 face(s)
#  - Sundar_Pichai from [True, True, True, True, True, False, True, True, True, True, True, True, True, True]
# Filename sara9.jpg, found 1 face(s)
# Filename 33.jpg, found 0 face(s)
# Filename 3.jpg, found 1 face(s)
#  - Sundar_Pichai from [True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# Filename 7.jpg, found 1 face(s)
#  - Sundar_Pichai from [False, True, True, True, True, True, True, True, True, True, True, True, True, True]
# Filename 19.jpg, found 0 face(s)
# Filename 22.jpg, found 3 face(s)
# Filename sara8.jpg, found 1 face(s)
# Filename 11.jpg, found 1 face(s)
#  - Sundar_Pichai from [True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# Filename snowdex_copypasta.jpg, found 11 face(s)
# Filename 10.jpg, found 1 face(s)
#  - Sundar_Pichai from [True, True, True, True, True, False, True, True, True, True, True, True, True, True]
# Filename 44.jpg, found 2 face(s)
#  - Sundar_Pichai from [True, True, True, True, True, False, True, True, True, True, True, True, True, True]
# Filename 6.jpg, found 1 face(s)
#  - Sundar_Pichai from [True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# Filename whos_dat.jpg, found 1 face(s)
# Filename 16.jpg, found 3 face(s)
#  - Sundar_Pichai from [True, True, True, False, True, False, True, True, True, True, False, True, True, True]
# Filename weirdo.jpg, found 1 face(s)
# Filename 1.jpg, found 1 face(s)
#  - Sundar_Pichai from [True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# Filename 20.jpg, found 2 face(s)
#  - Sundar_Pichai from [False, False, False, False, False, False, True, False, False, False, False, False, False, False]
# Filename 4.jpg, found 1 face(s)
#  - Sundar_Pichai from [True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# Filename 17.jpg, found 1 face(s)
#  - Sundar_Pichai from [True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# Filename 5.jpg, found 1 face(s)
#  - Sundar_Pichai from [True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# Filename 8.jpg, found 1 face(s)
#  - Sundar_Pichai from [True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# Filename 18.jpg, found 8 face(s)
#  - Sundar_Pichai from [False, False, False, False, False, False, False, False, False, False, True, False, False, False]
#  - Sundar_Pichai from [True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# Filename 14.jpg, found 1 face(s)
#  - Sundar_Pichai from [True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# Filename 55.jpg, found 1 face(s)
